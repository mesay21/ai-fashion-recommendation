# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import sys

import pandas as pd
from pandas.io.json import json_normalize

sys.path.append('../scripts')
#from train_bilstm import PolyPolyvoreDataset

# %%
json_file = '../data/labels/train_no_dup.json'
df = pd.read_json(json_file)
df
# Out:
#                                                     name  views  \
# 0                                                 Casual   8743
# 1      Being a Vans shoe model with Luke. Idk about t...    188
# 2                    These Chanel bags is a bad habit .x    562
# 3                               Avenger/Supernatural prp   2613
# 4                                              Boho (39)     62
# ...                                                  ...    ...
# 17311                                            2.15.17    183
# 17312                                              tweed   2428
# 17313                      TV Style: Pretty Little Liars   2184
# 17314                         60-Second Style: Work Wear   3147
# 17315                    Mini Dress: The Glamour Edition    111
#
#                                                    items  \
# 0      [{'index': 1, 'name': 'mock neck embroidery su...
# 1      [{'index': 1, 'name': 'nirvana distressed t-sh...
# ...

# %%
print(df['items'].iloc[0])
# Out:
# [{'index': 1, 'name': 'mock neck embroidery suede sweatshirt', 'price': 24.0, 'likes': 10, 'image': 'http://img2.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=194508109', 'categoryid': 4495}, {'index': 2, 'name': 'luxe double zip hooded jacket', 'price': 150.0, 'likes': 2250, 'image': 'http://img2.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=188778349', 'categoryid': 25}, {'index': 3, 'name': 'citizens humanity high rise rocket hem jean', 'price': 248.0, 'likes': 2437, 'image': 'http://img1.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=188977857', 'categoryid': 27}, {'index': 4, 'name': 'suede tie short boots', 'price': 37.0, 'likes': 2, 'image': 'http://img1.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=194942557', 'categoryid': 261}, {'index': 5, 'name': 'cloth travel school backpack', 'price': 22.0, 'likes': 2, 'image': 'http://img2.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=194941874', 'categoryid': 259}, {'index': 6, 'name': '', 'price': 160.0, 'likes': 3
# ...

# %%
len(set(df['name']))
set(df['name'])
# Out:
# 13669
# {'The Great Escape. ... The Beach',
#  'Pack and Go : Winter Getaway --- Somewhere in South Korea',
#  'Untitled #422',
#  'Casual outfit',
#  'Lana in a wedding',
#  'Romwe Black Denim Pants',
#  'Untitled #62',
#  'Workout Gear',
#  'Natural Beauty',
#  'Im gona make me so proud',
#  'Untitled #430',
#  'Adollia.com - 2',
#  'spring #160',
#  'OC challenge: Day twelve, formal wear.',
#  'DAY TO NIGHT: Denim shirt dress',
#  'Pretty Plus-Size Style',
#  'calum &lt;3',
#  'Outfit for Tori of Victorious at party',
#  'SHEINSIDE',
#  "Alphis Ashley's Formal Change",
#  'dia de la primavera',
#  'Netflix and chill with Niall',
#  'Spring Fashion - Yesstyle ♥',
#  'Dancing on my own',
#  '♡Miley♡',
#  'A Look to get you Noticed...Bold Stripes (TS Feb 4 2017 Thanx PV 😘)',
#  'Miley Look #2',
#  'Fall Look: Plus Size Dress',
#  'Easy peasy',
#  'Party time',
#  'Rosie on her first day',
#  'Bez tytułu #263',
#  'yellow sweater',
#  'Ariana Grande',
#  'nyfw street style: day 1',
# ...

# %%
df
# Out:
#                                                     name  views  \
# 0                                                 Casual   8743
# 1      Being a Vans shoe model with Luke. Idk about t...    188
# 2                    These Chanel bags is a bad habit .x    562
# 3                               Avenger/Supernatural prp   2613
# 4                                              Boho (39)     62
# ...                                                  ...    ...
# 17311                                            2.15.17    183
# 17312                                              tweed   2428
# 17313                      TV Style: Pretty Little Liars   2184
# 17314                         60-Second Style: Work Wear   3147
# 17315                    Mini Dress: The Glamour Edition    111
#
#                                                    items  \
# 0      [{'index': 1, 'name': 'mock neck embroidery su...
# 1      [{'index': 1, 'name': 'nirvana distressed t-sh...
# ...

# %%
df.name.value_counts()[:5]
# Out:
# Street Style                       126
# street style                       117
# Casual                             112
# Celebrate Our 10th Polyversary!     85
# School                              61
# Name: name, dtype: int64

# %%
df['items'].iloc[0]
# Out:
# [{'index': 1,
#   'name': 'mock neck embroidery suede sweatshirt',
#   'price': 24.0,
#   'likes': 10,
#   'image': 'http://img2.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=194508109',
#   'categoryid': 4495},
#  {'index': 2,
#   'name': 'luxe double zip hooded jacket',
#   'price': 150.0,
#   'likes': 2250,
#   'image': 'http://img2.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=188778349',
#   'categoryid': 25},
#  {'index': 3,
#   'name': 'citizens humanity high rise rocket hem jean',
#   'price': 248.0,
#   'likes': 2437,
#   'image': 'http://img1.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=188977857',
#   'categoryid': 27},
#  {'index': 4,
#   'name': 'suede tie short boots',
#   'price': 37.0,
#   'likes': 2,
#   'image': 'http://img1.polyvoreimg.com/cgi/img-thing?.out=jpg&size=m&tid=194942557',
#   'categoryid': 261},
#  {'index': 5,
#   'name': 'cloth travel school backpack',
#   'price': 22.0,
#   'likes': 2,
# ...

# %%
json_file = '../main/labels/test_no_dup.json'
test_df = pd.read_json(json_file)
test_df
# Out:
#                                                    name  views  \
# 0                                          Street Dance   2334
# 1     I Will Be Your Sunset If You'll Be My Silhouette!  15762
# 2                             Striped pants and Oxford!     37
# 3                   Dress Katy Perry for the Super Bowl    948
# 4                                         Edgy Urbanist   4946
# ...                                                 ...    ...
# 3071                                            Casual|      8
# 3072                                             Casual  20192
# 3073                                       Winter White    338
# 3074                        Hot Ticket: Rihanna Concert  11891
# 3075                                       Street Style     98
#
#                                                   items  \
# 0     [{'index': 1, 'name': 'dolce gabbana silk shir...
# 1     [{'index': 1, 'name': 'irregular lapel blue tr...
# ...

# %%
test_df.name.value_counts()[:40]
# Out:
# dress                                                   22
# Feminine Preppy School Girl Essentials                  21
# Street Style                                            18
# Casual                                                  16
# Work Wear                                               14
# Sporty                                                  10
# street style                                             8
# Go Sporty                                                7
# Boho                                                     7
# Vacation                                                 7
# Sporty Style                                             7
# Celebrate Our 10th Polyversary!                          6
# Love NewChic                                             6
# Win $20 Cash from Rosegal!                               6
# Carry On: Straw Bags                                     6
# Preppy                                                   6
# ...

# %%
if 'Printed Shorts' in list(df['name']):
    print('TRUE')
# Out:
# TRUE

# %%
df.shape[1]
# Out:
# 9

# %%
dictionary = {}
for i in range(df.shape[0]):
    length = len(df['items'].iloc[i])
    if length not in dictionary:
        dictionary[length] = 1
    else:
        dictionary[length] += 1
        
print(dictionary)
# Out:
# {7: 3207, 8: 6767, 6: 3077, 5: 2699, 4: 1566}

# %%
json_file = '../main/labels/test_no_dup.json'
df = pd.read_json(json_file)
df
dictionary = {}
for i in range(df.shape[0]):
    length = len(df['items'].iloc[i])
    if length not in dictionary:
        dictionary[length] = 1
    else:
        dictionary[length] += 1
        
print(dictionary)
# Out:
#                                                    name  views  \
# 0                                          Street Dance   2334
# 1     I Will Be Your Sunset If You'll Be My Silhouette!  15762
# 2                             Striped pants and Oxford!     37
# 3                   Dress Katy Perry for the Super Bowl    948
# 4                                         Edgy Urbanist   4946
# ...                                                 ...    ...
# 3071                                            Casual|      8
# 3072                                             Casual  20192
# 3073                                       Winter White    338
# 3074                        Hot Ticket: Rihanna Concert  11891
# 3075                                       Street Style     98
#
#                                                   items  \
# 0     [{'index': 1, 'name': 'dolce gabbana silk shir...
# 1     [{'index': 1, 'name': 'irregular lapel blue tr...
# ...
